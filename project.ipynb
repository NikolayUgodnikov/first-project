# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Алексей, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# Критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <br/>
# <div class="alert alert-info">
# Добрый день!
#
# Дошел до **Шаг 5. Обучение моделей** Задача1.
# Дальше в построении моделей продвинуться не удается, вижу эту ошибку (ниже).
# + NameError: name 'data_preprocessor' is not defined
#
# Возможно, некорректно загрузились библиотеки?
#
#
#
#
#
# По Задаче2 отработал шаги до  **"Шаг 4. Добавление нового входного признака"**, где нужны предсказания первой модели.
# Благодарю за обратную связь.
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Комментарий ревьюера </b>
#
# Алексей, перезапустил проект на своей стороне и не воспроивзёл эту ошибку - возможно, ты просто ссылался на переменную, которую ранее удалил или переименовал.
#
# Вместе с тем обрати внимание, что при попытке воспроизвести проект на платформе я получил три типа ошибок:
#
# - использование неимпортированного модуля в разделе анализа корреляции;
# - использование устаревшего параметра для разреженной матрицы у `OneHotEncoder`;
# - ссылка на несуществующий столбец при отрисовке графика в конце работы.
#
#  Устрани, пожалуйста, эти ошибки, а также доделай проект до конца, чтобы мы с тобой смогли поработать над твоим проектом.
#
#
# <br/>
# <div class="alert alert-info">
# исправил, работает
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ментора <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %%
# !pip install phik==0.10.0 -q

# %%
# !pip install shap -q

# %%
# !pip install --upgrade scikit-learn -q

# %%
#импорт необходимых библиотек
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import make_classification
from sklearn import svm
from sklearn import model_selection, metrics
from sklearn.metrics import make_scorer
import phik
from phik.report import plot_correlation_matrix
from phik import report
from sklearn.impute import SimpleImputer 
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %% [markdown]
# **ЗАДАЧА 1: предсказание уровня удовлетворённости сотрудника**

# %% [markdown]
# **Шаг 1. Загрузка данных**

# %%
df_train = pd.read_csv('/datasets/train_job_satisfaction_rate.csv')
df_test = pd.read_csv('/datasets/test_features.csv')
df_target = pd.read_csv('/datasets/test_target_job_satisfaction_rate.csv')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных можно задать индекс-столбец - за это действие отвечает параметр `index_col`.

# %% [markdown]
# **Шаг 2. Предобработка данных**

# %% [markdown]
# + тренировочные данные

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %% [markdown]
# В таблице 4000 строк, 10 столбцов. Видим наличие пропусков в столбцах "dept" и "level".
# Посмотрим на наличие ошибок в заполнении данных.

# %%
df_train_cat_col = list(df_train.select_dtypes(['object']).columns)
for i in df_train_cat_col:
    print(i, df_train[i].unique())
# Out:
# dept ['sales' 'hr' 'technology' 'purchasing' 'marketing' nan]
# level ['junior' 'middle' 'sinior' nan]
# workload ['medium' 'high' 'low']
# last_year_promo ['no' 'yes']
# last_year_violations ['no' 'yes']

# %% [markdown]
# Ошибок в заполнении данных не обнаружено.

# %%
df_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %% [markdown]
# + тестовые данные

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %% [markdown]
# В таблице 2000 строк, 9 столбцов. Есть пропуски в столбцах "dept" и "level".
# Посмотрим на наличие ошибок в заполнении данных.

# %%
df_test_cat_col = list(df_test.select_dtypes(['object']).columns)
for i in df_test_cat_col:
    print(i, df_test[i].unique())
# Out:
# dept ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan ' ']
# level ['junior' 'middle' 'sinior' nan]
# workload ['medium' 'low' 'high' ' ']
# last_year_promo ['no' 'yes']
# last_year_violations ['no' 'yes']

# %% [markdown]
# В столбцах 'dept' и 'workload' присутствуют пробелы.
# Посмотрим эти строки.

# %%
df_test1 = df_test.loc[(df_test['dept'] == " ")]
df_test1
# Out:
#           id dept   level workload  employment_years last_year_promo  \
# 1699  822186       middle   medium                 3              no
#
#      last_year_violations  supervisor_evaluation  salary
# 1699                   no                      4   38400

# %%
df_test2 = df_test.loc[(df_test['workload'] == " ")]
df_test2
# Out:
#         id       dept   level workload  employment_years last_year_promo  \
# 15  590867  marketing  junior                          4              no
#
#    last_year_violations  supervisor_evaluation  salary
# 15                   no                      4   28800

# %%
#заменим пробелы пропусками.
df_test = df_test.replace(r'\s+', np.nan, regex=True)

# %%
#замена произведена
df_test_cat_col = list(df_test.select_dtypes(['object']).columns)
for i in df_test_cat_col:
    print(i, df_test[i].unique())
# Out:
# dept ['marketing' 'hr' 'sales' 'purchasing' 'technology' nan]
# level ['junior' 'middle' 'sinior' nan]
# workload ['medium' 'low' 'high' nan]
# last_year_promo ['no' 'yes']
# last_year_violations ['no' 'yes']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Аномалия обработана корректно. В целом она могла бы быть обработана и в `Pipeline`, при настройке энкодеров на обработку новых значений признаков, которые не были на момент обучения энкодера.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Также можно было бы исправить ошибку в `sinior`.

# %% [markdown]
# Ошибки в заполнении исправлены.

# %% [markdown]
# + рассмотрим данные с целевым признаком

# %%
df_target.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %%
df_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# 2000 строк в 2-х столбцах. Пропусков нет.

# %% [markdown]
# + оценим количество пропусков

# %%
df_train.isna().sum()
# Out:
# id                       0
# dept                     6
# level                    4
# workload                 0
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# job_satisfaction_rate    0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# id                       0
# dept                     3
# level                    1
# workload                 1
# employment_years         0
# last_year_promo          0
# last_year_violations     0
# supervisor_evaluation    0
# salary                   0
# dtype: int64

# %%
df_target.isna().sum()
# Out:
# id                       0
# job_satisfaction_rate    0
# dtype: int64

# %% [markdown]
# Пропуски в первом и втором датасете незначительны и не должны влиять на результат анализа. По условиям задачи, заменим их с помощью пайплайна.

# %% [markdown]
# + посчитаем явные дубликаты

# %%
#тренировочная выборка
df_train.duplicated().sum()
# Out:
# 0

# %%
#тестовая выборка
df_test.duplicated().sum()
# Out:
# 0

# %%
#для целевого признака
df_target.duplicated().sum()
# Out:
# 0

# %% [markdown]
# + проверим корректность типов данных

# %%
df_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %%
df_train.dtypes
# Out:
# id                         int64
# dept                      object
# level                     object
# workload                  object
# employment_years           int64
# last_year_promo           object
# last_year_violations      object
# supervisor_evaluation      int64
# salary                     int64
# job_satisfaction_rate    float64
# dtype: object

# %% [markdown]
# Ошибок в типах данных не наблюдаем.

# %%
df_test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %%
df_test.dtypes
# Out:
# id                        int64
# dept                     object
# level                    object
# workload                 object
# employment_years          int64
# last_year_promo          object
# last_year_violations     object
# supervisor_evaluation     int64
# salary                    int64
# dtype: object

# %% [markdown]
# Ошибок в типах данных не наблюдаем.

# %%
df_target.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %%
df_target.dtypes
# Out:
# id                         int64
# job_satisfaction_rate    float64
# dtype: object

# %% [markdown]
# И здесь с типами данных порядок.

# %% [markdown]
# ВЫВОД:
# Загружены 3 датасета. В тренировочных данных нет ошибок, есть пропуски. В тестовых данных также есть пропуски, плюс выявлены ошибки в столбцах 'dept' и 'workload', заменены на NaN. В третьей таблице пропусков и ошибок не выявлено. Проведена проверка на дубликаты. Проанализирована корректность типов данных. Замена пропусков будет проведена на этапе работы с пайплайнами.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Предобработка данных выполнена корректно.

# %% [markdown]
# **Шаг 3. Исследовательский анализ данных**

# %% [markdown]
# + оценим распределение данных в сете df_train

# %%
df_train.describe()
# Out:
#                   id  employment_years  supervisor_evaluation        salary  \
# count    4000.000000       4000.000000            4000.000000   4000.000000
# mean   544957.621000          3.718500               3.476500  33926.700000
# std    257883.104622          2.542513               1.008812  14900.703838
# min    100954.000000          1.000000               1.000000  12000.000000
# 25%    322836.750000          2.000000               3.000000  22800.000000
# 50%    534082.500000          3.000000               4.000000  30000.000000
# 75%    771446.000000          6.000000               4.000000  43200.000000
# max    999521.000000         10.000000               5.000000  98400.000000
#
#        job_satisfaction_rate
# count            4000.000000
# mean                0.533995
# std                 0.225327
# min                 0.030000
# 25%                 0.360000
# 50%                 0.560000
# 75%                 0.710000
# max                 1.000000

# %%
df_train_1 = df_train.drop('id', axis=1)
df_train_cat_col = list(df_train_1.select_dtypes(['object']).columns)
df_train_num_col = list(df_train_1.select_dtypes(['int64', 'float64']).columns)

# %% [markdown]
# + Гистограммы **непрерывных числовых** столбцов

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
plt.suptitle('Непрерывные числовые показатели', fontsize=26)

axs[0].hist(df_train['salary'], bins=40)
axs[1].hist(df_train['job_satisfaction_rate'], bins=40)

axs[0].set_title('salary', fontsize=20)
axs[1].set_title('job_satisfaction_rate', fontsize=20)
axs[0].set_ylabel('Количество', fontsize=16)
axs[0].set_xlabel('Доход', fontsize=16)
axs[1].set_xlabel('Доля удовлетворённости', fontsize=16)
axs[1].set_ylabel('Количество', fontsize=16);

# %% [markdown]
# + Гистограммы **дискретных числовых** столбцов

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
plt.suptitle('Дискретные числовые показатели', fontsize=26)

sns.countplot(data= df_train, x='supervisor_evaluation', ax=axs[0], color = 'darkred')
sns.countplot(data= df_train, x='employment_years', ax=axs[1], color = 'darkred')

axs[0].set_title('supervisor_evaluation', fontsize=20)
axs[1].set_title('employment_years', fontsize=20)
axs[0].set_ylabel('Количество', fontsize=16)
axs[1].set_ylabel('', fontsize=16)
axs[0].set_xlabel('Оценка руководства', fontsize=16)
axs[1].set_xlabel('Лет в компании', fontsize=16);

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. `employment_years` и `supervisor_evaluation` - дискретные признаки, для их анализа нужнен тип графиков, который на каждое уникальные значение признака строит свою корзину. Например, можно использовать `sns.countplot`.
#
# 2. `id` следует исключить из анализа - с точки зрения наличия в нём ценной информации этот признак бесполезен. Тут и далее.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# + время работы ('employment_years')
# Основная масса сотрудников работатает 3 года и менее. Это может быть связано либо с резким увеличением штата (в связи с экспансией на рынке), либо с текучкой кадров (из-за неконкурентных условий труда).
# + оценка работодателя ('supervisor_evaluation')
# Наиболее популярные оценки результатов труда 3 и 4. Возможно, это связано с малым стажем/опытом работы большинства сотрудников.
# + зарплата ('salary')
# Большинство сотрудников получают зарплату в пределах от 20 до 40 тыс. руб. Также имеется группа лиц получающих больше 80 тысяч (руководители, сотрудники с экспертными компетенциями), максимум же составляет 98400 руб.(видимо, у топ-менеджмента).
# + удовлетворенность ('job_satisfaction_rate')
# Видим 2 пика, от 0.6 до 0.8, т.е. те сотрудники, которых в целом всё устраивает, кроме отдельных нюансов. И пик на 0,4 -это те которые думают над уходом. Минимальных (готовы уходить) значений мало. Как и максимальных (всё устраивает). Картина выглядит упраляемой для менеджмента и владельцев. В моменте, массовых увольнений не ожидается. Вопрос - какие меры предпримут десижн-мейкеры для удержания сотрудников.

# %%
for i in df_train_num_col:
    plt.title(f'Boxplot для {i}')
    df_train.boxplot(column=i)
    plt.ylabel('Значение')
    plt.show();

# %% [markdown]
# Распределение нормальное, явных аномалий нет. Есть указанные выше выбросы по уровню зарплаты, но это не аномалии. Такая политика в данной компании: серьезный разрыв в зарплате между руководителями и экспертами, с одной стороны, и основной массой работников с другой.

# %%
df_train_cat_col = list(df_train.select_dtypes(['object']).columns)
for i in df_train_cat_col:
    df_train_group = df_train.groupby(i)['job_satisfaction_rate'].count().sort_values(ascending=False)
    plt.pie(df_train_group, labels=df_train_group.index, autopct='%1.1f%%')
    plt.title(f'Распределение {i}');
    plt.show();

# %% [markdown]
# Все категориальные признаки несбаласированны;
#
# Наибольшее количество сотрудников работает в продажах, далее идут технологи. Видимо, компания занимается продажей товаров и/или услуг.
#
# Большинство сотрудников либо новички, либо со средним опытом работы. Профессионалов всего 9 % от общего числа.
# Более половины сотрудников загружено на работе средне. Всего 3 % сотрудников получили повышение за последний год, это противоречит версии с резким увеличением штата. Если оргструктура не меняется, люди не растут, при этом масса новичков, - это говорит о текучке кадров и нелучших условиях труда.
#
# 14 % сотрудников за последний год нарушали трудовой договор. Очевидно, это довольно высокий показатель.

# %% [markdown]
# Теперь оценим распределения для **df_test**.

# %% [markdown]
# + Гистограммы **непрерывных числовых** столбцов

# %%
df_test['salary'].hist()
plt.title("Распределение сотрудников по уровню дохода")
plt.xlabel('Доход')
plt.ylabel('Количество')
plt.show();

# %% [markdown]
# + Гистограммы **дискретных числовых** столбцов

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
plt.suptitle('Дискретные числовые показатели', fontsize=26)

sns.countplot(data= df_test, x='supervisor_evaluation', ax=axs[0], color = 'darkred')
sns.countplot(data= df_test, x='employment_years', ax=axs[1], color = 'darkred')

axs[0].set_title('supervisor_evaluation', fontsize=20)
axs[1].set_title('employment_years', fontsize=20)
axs[0].set_ylabel('Количество', fontsize=16)
axs[1].set_ylabel('', fontsize=16)
axs[0].set_xlabel('Оценка руководства', fontsize=16)
axs[1].set_xlabel('Лет в компании', fontsize=16);

# %%
df_test_1 = df_test.drop('id', axis=1)
df_test_cat_col = list(df_test_1.select_dtypes(['object']).columns)
df_test_num_col = list(df_test_1.select_dtypes(['int64', 'float64']).columns)

# %%
for i in df_test_num_col:
    plt.title(f'Boxplot для {i}')
    df_test.boxplot(column=i)
    plt.ylabel('Значение')
    plt.show();

# %% [markdown]
# Значения в тестовой выборке по соответствующим параметрам распределены аналогично тренировочной.
# + время работы ('employment_years')
# + оценка работодателя ('supervisor_evaluation')
# + зарплата ('salary')
# + удовлетворенность ('job_satisfaction_rate')
#
# Данные готовы к дальнейшему использованию.

# %% [markdown]
# + оценим распределения для целевого признака

# %%
df_target.describe()
# Out:
#                   id  job_satisfaction_rate
# count    2000.000000             2000.00000
# mean   552765.213500                0.54878
# std    253851.326129                0.22011
# min    100298.000000                0.03000
# 25%    339052.000000                0.38000
# 50%    550793.000000                0.58000
# 75%    765763.750000                0.72000
# max    999029.000000                1.00000

# %%
df_target['job_satisfaction_rate'].hist()
plt.title("Распределение сотруднику по уровню удовлетворенности")
plt.xlabel('Уровень удовлетворенности')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# Как мы видим, большинство сотрудников готовы работать далее. С скорее довольны работой, чем нет. Негативный настрой "уволиться в ближайшее время" в явном меньшинстве. С другой стороны, уровень удовлетворенности для основной массы работников это "скорее Да", чем "Да".

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный EDA признаков.

# %% [markdown]
# + **таблица корреляций для тренировочной выборки**

# %% [markdown]
# Поскольку некоторые из количественных признаков распределены ненормально и имеется большое количество категориальных признаков, то анализ корреляции будем проводить с помощью библиотеки phik.

# %%
#вычисление матрицы корреляции
corr_matrix = df_train.drop(['id'], axis=1).phik_matrix(interval_cols=['salary', 
                                                                   'job_satisfaction_rate'])


#визуализация матрицы корреляции 
plt.figure(figsize=(12, 12))
sns.heatmap(corr_matrix, annot=True, cmap='Greens')
plt.title('Тренировочная выборка')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> `employment_years` и `supervisor_evaluation` - дискретные признаки, их не нужно передавать в `interval_cols`.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Наблюдается высокая корреляция между следующими признаками:
#
# /уровнем занимаемой должности и /длительностью работы в компании;
# /уровнем занимаемой должности и /зарплатой;
# /уровнем загруженности сотрудника и /зарплатой.
#
# Также заметна корреляция между /целевым признаком и /оценкой качества работы и /нарушениями трудового договора.
#
# При этом, для мультиколлениарности необходимо, чтобы коэффициент корреляции был более >0.9. В имеющихся данных такого высокого уровня зависимости не наблюдается.

# %%
#вычисление матрицы корреляции
corr_matrix_2 = df_test.drop(['id'], axis=1).phik_matrix(interval_cols=['salary'])


#визуализация матрицы корреляции 
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix_2, annot=True, cmap='Greens')
plt.title('Тестовая выборка')
plt.show()

# %% [markdown]
# Как мы видим значения корреляции, практически, идентичны основной выборке. Это говорит о равномерном распределении данных и потенциально высоком уровне прогноза на их основании.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Есть анализ корреляции - молодец, что используешь `phik` для анализа и нелинейных зависимостей, а также настраиваешь `interval_cols` для корректной оценки корреляции для переменных разного типа.

# %% [markdown]
# **ВЫВОД**
# По итогам исследовательского анализа данных могу сказать следующее:
#
# По тренировочным данным:
# время работы ('employment_years')
# Основная масса сотрудников работатает 3 года и менее. Это может быть связано либо с резким увеличением штата (в связи с экспансией на рынке), либо с текучкой кадров (из-за неконкурентных условий труда).
# оценка работодателя ('supervisor_evaluation')
# Наиболее популярные оценки результатов труда 3 и 4. Возможно, это связано с малым стажем/опытом работы большинства сотрудников.
# зарплата ('salary')
# Большинство сотрудников получают зарплату в пределах от 20 до 40 тыс. руб. Также имеется группа лиц получающих больше 80 тысяч (руководители, сотрудники с экспертными компетенциями), максимум же составляет 98400 руб.(видимо, у топ-менеджмента).
# удовлетворенность ('job_satisfaction_rate')
# Видим 2 пика, от 0.6 до 0.8, т.е. те сотрудники, которых в целом всё устраивает, кроме отдельных нюансов. И пик на 0,4 -это те которые думают над уходом. Минимальных (готовы уходить) значений мало. Как и максимальных (всё устраивает). Картина выглядит упраляемой для менеджмента и владельцев. В моменте, массовых увольнений не ожидается. Вопрос - какие меры предпримут десижн-мейкеры для удержания сотрудников.
#
# По тестовым данным:
# Большинство сотрудников работают менее 4-х лет в компании.
# Уровень зарплаты такой же как и в тренировочных данных.
# Лидером по оценкам является 4-ка, второе место занимает 3-ка. Работодатель оценивает сотрудников аналогично.
# В тестовых данных видим преобладание сотрудников, связанных с продажами.
# Загруженность на тестовых данных совпадает с тренировочными.
# Также 3 % сотрудников получили за последний год повышение.
# 14 % сотрудников нарушили трудовой договор за последний год.
#
# По целевым данным:
# Большинство сотрудников желает остаться работать. И сомневаются стоит ли уходить. Пик приходится на значения от 0.6 до 0.8.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что не забываешь делать промежуточные выводы.

# %% [markdown]
# **Шаг 4. Подготовка данных**

# %% [markdown]
# Данные образуют три группы, требующие разных кодировок:
#
# + 1.dept, last_year_promo, last_year_violations — нужно кодировать с помощью OneHotEncoder.
# + 2.level, workload — нужно кодировать с помощью OrdinalEncoder.
# + 3.employment_years, supervisor_evaluation, salary - нужно масштабировать.
#
# Пропуски будем устранять пайплайне.
# Целевой признак — job_satisfaction_rate.

# %%
df_train.describe()
# Out:
#                   id  employment_years  supervisor_evaluation        salary  \
# count    4000.000000       4000.000000            4000.000000   4000.000000
# mean   544957.621000          3.718500               3.476500  33926.700000
# std    257883.104622          2.542513               1.008812  14900.703838
# min    100954.000000          1.000000               1.000000  12000.000000
# 25%    322836.750000          2.000000               3.000000  22800.000000
# 50%    534082.500000          3.000000               4.000000  30000.000000
# 75%    771446.000000          6.000000               4.000000  43200.000000
# max    999521.000000         10.000000               5.000000  98400.000000
#
#        job_satisfaction_rate
# count            4000.000000
# mean                0.533995
# std                 0.225327
# min                 0.030000
# 25%                 0.360000
# 50%                 0.560000
# 75%                 0.710000
# max                 1.000000

# %%
df_test.describe()
# Out:
#                   id  employment_years  supervisor_evaluation        salary
# count    2000.000000       2000.000000            2000.000000   2000.000000
# mean   552765.213500          3.666500               3.526500  34066.800000
# std    253851.326129          2.537222               0.996892  15398.436729
# min    100298.000000          1.000000               1.000000  12000.000000
# 25%    339052.000000          1.000000               3.000000  22800.000000
# 50%    550793.000000          3.000000               4.000000  30000.000000
# 75%    765763.750000          6.000000               4.000000  43200.000000
# max    999029.000000         10.000000               5.000000  96000.000000

# %%
df_target.describe()
# Out:
#                   id  job_satisfaction_rate
# count    2000.000000             2000.00000
# mean   552765.213500                0.54878
# std    253851.326129                0.22011
# min    100298.000000                0.03000
# 25%    339052.000000                0.38000
# 50%    550793.000000                0.58000
# 75%    765763.750000                0.72000
# max    999029.000000                1.00000

# %% [markdown]
# **Шаг 5. Обучение моделей**

# %%
df_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %%
df_test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %%
df_target.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %%
target_all = df_test.merge(df_target, how='left')
display(target_all.head())
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# 4                   no                      5   40800                   0.75

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут неправильно соединены таблицы: мы должны соединить `X` и `y` для `test` - это переменные `df_test` и `df_target`, ты же соединил `train` и `test` выборки.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
target_all[target_all.columns[target_all.columns != 'id']].describe()
# Out:
#        employment_years  supervisor_evaluation        salary  \
# count       2000.000000            2000.000000   2000.000000
# mean           3.666500               3.526500  34066.800000
# std            2.537222               0.996892  15398.436729
# min            1.000000               1.000000  12000.000000
# 25%            1.000000               3.000000  22800.000000
# 50%            3.000000               4.000000  30000.000000
# 75%            6.000000               4.000000  43200.000000
# max           10.000000               5.000000  96000.000000
#
#        job_satisfaction_rate
# count             2000.00000
# mean                 0.54878
# std                  0.22011
# min                  0.03000
# 25%                  0.38000
# 50%                  0.58000
# 75%                  0.72000
# max                  1.00000

# %%
train_1 = df_train.drop(['id'], axis=1)
train_1.drop_duplicates(inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что удаляешь дубликаты после удаления `id`, а также делаешь это только в `train`.

# %%
test_1 = target_all.drop(['job_satisfaction_rate','id'], axis=1)

target_1 = target_all['job_satisfaction_rate']

# %%
#формируем выборки
RANDOM_STATE = 100

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Переменная `TEST_SIZE` не используется в проекте - стоит удалить.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
X_train = train_1.drop('job_satisfaction_rate', axis=1)
y_train = train_1['job_satisfaction_rate'] 
X_test = test_1
y_test = target_1

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
#
# Делая копию или срез какой-то таблицы, стоит использовать метод `copy()`: используя простое присвивание вида `a=b`, мы в переменную `a` помещаем не новый и самостоятельный объект в памяти, а всего лишь новую ссылку на объект в памяти, на который ссылается `b`. Как итог, внеся изменения в `a`, ты увидишь их и в `b`, и наоборот. Метод `copy()` позволяет создавать именно новые объекты в памяти.

# %%
#создаем списки признаков
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations'] #'
ord_columns = ['level', 'workload']
num_columns = ['employment_years', 'supervisor_evaluation', 'salary']

#заполняем пропуски наиболее частыми значениями
#задаем параметры моделей
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
)

ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'], 
                    ['low', 'medium', 'high']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),

    ]
)

data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', LinearRegression())
])

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.

# %%
param_grid = [

    {
        'models': [LinearRegression()],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(5, 15),
        'models__max_features': range(5, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Для гиперпараметра `max_depth` рассматривается очень длинная последовательность: деревья с большой глубиной склонны к переобучению, а обучаются и предсказывают результат они дольше, поэтому делать их слишком глубокими не стоит - оптимальное значение почти всегда лежит в диапазоне от 2 до 5-6. Кроме того, можно попробовать значение `None` - в итоге оптимальная последовательность может выглядеть как `[None] + [i for i in range(2, 7)]`.
# </div>

# %%
#считаем специальную метрику sMAP
def smape(y_true, y_pred):
    return 100/len(y_true) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))
   
smape_scorer = make_scorer(score_func=smape, greater_is_better=False)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть функция для оценки `sMAPE`, а также пользовательский скорринг для кросс-валидации - супер!
# </div>

# %%
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    n_jobs=-1,
    cv=5,
    scoring=smape_scorer
)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
# ...

# %%
best_model = grid_search.best_estimator_
print('Лучшая модель и её параметры:\n\n', grid_search.best_estimator_)
print ('Метрика лучшей модели на кросс-валидации:', grid_search.best_score_*(-1))
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['dept', 'last_year_promo',
#                                                    'last_year_violations']),
#                                                  ('ord',
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучшая модель.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание, что оценка получена на кросс-валидации, а не на `train` выборке - очень важно корректно разделять эти сущности.
#
# На `train` оценка выглядела бы сделующим образом:
#
#     model.fit(x_train, y_train)
#     preds = model.predict(x_train)
#
#     smape(y_train, preds)
#
# Текст в выводе кода стоит поправить, указав оценку на кросс-валидации.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
print(f'Метрика sMAPE лучшей модели на тестовых данных: {round(smape(y_test, best_model.predict(X_test)),4)}')
# Out:
# Метрика sMAPE лучшей модели на тестовых данных: 14.5585

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Выполнена оценка лучшей модели на `test`.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Убедись, что после исправления замечаний метрика будет в допустимом диапазоне `<= 15`.
#
# Очень важно также проверить лучшую модель на адекватность, сравнив качество её предсказаний с качеством модели, которая предсказывала бы константу - вдруг окажется, что не было бы большого смысла заниматься созданием новых признаков, тюнингом и кросс-валидацией моделей, если можно было бы просто предсказывать среднее значение тренировочной выборки?
#
# В качестве константной модели можно использовать `DummyRegressor` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyRegressor.html) -  эта модель как раз создана для генерирования константных предсказаний.
#
# Важно, чтобы результат тестирования нашей модели на тествой выборке был лучше, чем результат константной модели - в противном случае наша модель является бесполезной, так как все наши усилия над проектом не принесли результата, а можель, просто предсказывющая среднее на `train`, делает нашу работу лучше.

# %% [markdown]
# **Шаг 6. Оформление выводов**

# %% [markdown]
# По итогам **предобработки** данных могу сделать следующие выводы:
# Пропуски в таблицах data_train и data_test, общее количество незначительно и не превышает 1 % от общего массива данных. По техническому заданию их нужно будет заполнить в паплайне.
# Явные дубликаты в данных не выявлены.
#
# По итогам **исследовательского анализа** данныхе:
#
# По тренировочным данным:
# время работы ('employment_years') Основная масса сотрудников работатает 3 года и менее. Это может быть связано либо с резким увеличением штата (в связи с экспансией на рынке), либо с текучкой кадров (из-за неконкурентных условий труда). оценка работодателя ('supervisor_evaluation') Наиболее популярные оценки результатов труда 3 и 4. Возможно, это связано с малым стажем/опытом работы большинства сотрудников. зарплата ('salary') Большинство сотрудников получают зарплату в пределах от 20 до 40 тыс. руб. Также имеется группа лиц получающих больше 80 тысяч (руководители, сотрудники с экспертными компетенциями), максимум же составляет 98400 руб.(видимо, у топ-менеджмента). удовлетворенность ('job_satisfaction_rate') Видим 2 пика, от 0.6 до 0.8, т.е. те сотрудники, которых в целом всё устраивает, кроме отдельных нюансов. И пик на 0,4 -это те которые думают над уходом. Минимальных (готовы уходить) значений мало. Как и максимальных (всё устраивает). Картина выглядит упраляемой для менеджмента и владельцев. В моменте, массовых увольнений не ожидается. Вопрос - какие меры предпримут десижн-мейкеры для удержания сотрудников.
#
# По тестовым данным:
# Большинство сотрудников работают менее 4-х лет в компании. Уровень зарплаты такой же как и в тренировочных данных. Лидером по оценкам является 4-ка, второе место занимает 3-ка. Работодатель оценивает сотрудников аналогично. В тестовых данных видим преобладание сотрудников, связанных с продажами. Загруженность на тестовых данных совпадает с тренировочными. Также 3 % сотрудников получили за последний год повышение. 14 % сотрудников нарушили трудовой договор за последний год.
#
# По целевым данным:
# Большинство сотрудников желает остаться работать. И сомневаются стоит ли уходить. Пик приходится на значения от 0.6 до 0.
#
# Для поиска **лучшей модели** были предприняты следующие шаги:
#
# проведено исследование полученных даных и признаков
# в процессе поиска к данным применено 2 типа моделей классифкации
# на основе метрики SMAPE была отобрана лучшая модель ('models', DecisionTreeRegressor(max_depth=13, max_features=11,   random_state=100) c использованием пайплайна
# метрика SMAPE лучшей модели составила: 15,7
# на тестовых данных значение улучшилось

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть промеуточный вывод по задаче - отлично!

# %% [markdown]
# **ЗАДАЧА 2: Предсказание увольнения сотрудника из компании**

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Для этой задачи аналогичны все замечания из предыдущей в части аналогичных активностей.

# %% [markdown]
# **Шаг 1. Загрузка данных**

# %% [markdown]
# Загрузите данные из файлов:
# Тренировочная выборка:
# train_quit.csv
# Входные признаки тестовой выборки те же, что и в прошлой задаче:
# test_features.csv
# Целевой признак тестовой выборки:
# test_target_quit.csv

# %%
#загрузим датасеты для Задачи2
#по условиям, тестовая выборка та же, что и для Задачи1
data_train = pd.read_csv('/datasets/train_quit.csv')
data_test = pd.read_csv('/datasets/test_features.csv')
data_target = pd.read_csv('/datasets/test_target_quit.csv')

# %% [markdown]
# **Шаг 2. Предобработка данных**

# %%
data_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
data_test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %%
data_target.head()
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %%
data_train['id'].nunique()
# Out:
# 4000

# %%
data_target['id'].nunique()
# Out:
# 2000

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB

# %%
data_target
# Out:
#           id quit
# 0     999029  yes
# 1     372846   no
# 2     726767   no
# 3     490105   no
# 4     416898  yes
# ...      ...  ...
# 1995  836109  yes
# 1996  180999  yes
# 1997  746018   no
# 1998  247658   no
# 1999  460332  yes
#
# [2000 rows x 2 columns]

# %% [markdown]
# 4000 строк в 10 столбцах. Пропусков нет.

# %%
#проверим на наличие ошибок
data_train_cat_col = list(data_test.select_dtypes(['object']).columns)
for i in data_train_cat_col:
    print(i, data_train[i].unique())
# Out:
# dept ['sales' 'purchasing' 'marketing' 'technology' 'hr']
# level ['middle' 'junior' 'sinior']
# workload ['high' 'medium' 'low']
# last_year_promo ['no' 'yes']
# last_year_violations ['no' 'yes']

# %% [markdown]
# Ошибок нет.

# %%
data_target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# 2000 строк в 2-х колонках. Пропусков нет.

# %%
data_train.duplicated().sum()
# Out:
# 0

# %%
data_target.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты не обнаружены.

# %%
data_train.dtypes
# Out:
# id                        int64
# dept                     object
# level                    object
# workload                 object
# employment_years          int64
# last_year_promo          object
# last_year_violations     object
# supervisor_evaluation     int64
# salary                    int64
# quit                     object
# dtype: object

# %%
data_target.dtypes
# Out:
# id       int64
# quit    object
# dtype: object

# %% [markdown]
# В типах данных ошибок нет.

# %% [markdown]
# **Шаг 3. Исследовательский анализ данных**

# %% [markdown]
# + оценим распределение данных в сете data_train

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB

# %%
data_train.head(10)
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
# 5  699916       sales  junior      low                 1              no
# 6  417070  technology  middle   medium                 8              no
# 7  165489       sales  middle      low                 4              no
# 8  996399   marketing  middle      low                 7              no
# 9  613206  technology  middle   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# ...

# %% [markdown]
# + гистограммы непрерывных числовых показателей

# %%
data_train['salary'].hist()
plt.title("Распределение сотрудников по уровню дохода")
plt.xlabel('Доход')
plt.ylabel('Количество')
plt.show();

# %% [markdown]
# Отметим, что распределение по уровню дохода аналогично тренировочной выборке Задачи1. Большинство получает 20-40 тр. И есть небольшая группа руководителей/экспертов, имеющая 80-100 тр.

# %% [markdown]
# + гистограммы дискретных числовых показателей

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 6))
plt.suptitle('Дискретные числовые показатели', fontsize=26)

sns.countplot(data= data_train, x='supervisor_evaluation', ax=axs[0], color = 'darkred')
sns.countplot(data= data_train, x='employment_years', ax=axs[1], color = 'darkred')

axs[0].set_title('supervisor_evaluation', fontsize=20)
axs[1].set_title('employment_years', fontsize=20)
axs[0].set_ylabel('Количество', fontsize=16)
axs[1].set_ylabel('', fontsize=16)
axs[0].set_xlabel('Оценка руководства', fontsize=16)
axs[1].set_xlabel('Лет в компании', fontsize=16);

# %% [markdown]
# supervisor_evaluation - 3 и 4 балла. employment_years - <4 лет для основной массы работников.

# %% [markdown]
# + рассмотрим качественные признаки в % соотношении

# %%
data_train['dept'].value_counts().plot(y = 'count', kind = 'pie', autopct='%1.0f%%', title = 'Подразделение', figsize = (14, 6))
plt.show()

# %%
data_train['level'].value_counts().plot(y = 'count', kind = 'pie', autopct='%1.0f%%', title = 'Уровень', figsize = (14, 6))
plt.show()

# %%
data_train['workload'].value_counts().plot(y = 'count', kind = 'pie', autopct='%1.0f%%', title = 'Нагрузка', figsize = (14, 6))
plt.show()

# %%
data_train['last_year_promo'].value_counts().plot(y = 'count', kind = 'pie', autopct='%1.0f%%', title = 'Повышение', figsize = (14, 6))
plt.show()

# %%
data_train['last_year_violations'].value_counts().plot(y = 'count', kind = 'pie', autopct='%1.0f%%', title = 'Нарушение ТД', figsize = (14, 6))
plt.show()

# %%
data_train['quit'].value_counts().plot(y = 'count', kind = 'pie', autopct='%1.0f%%', title = 'Увольнение', figsize = (14, 6))
plt.show()

# %% [markdown]
# ВЫВОД:
# интересно, с точки зрения рекомендаций для бизнес, что высокая и средняя нагрузка в сумме дают **70% сотрудников**. При этом, половина всех сотрудников - джуны, и большая часть работает не более 2-3 лет. Подобные "соковыжимательный" подход, в сочетании со стагнацией в карьерном и зарплатном росте провоцируют нарушения и текучку кадров (свыше 1/4 всего коллектива за год).

# %% [markdown]
# + таблица корреляций для тренировочной выборки

# %% [markdown]
# Поскольку некоторые их количественных признаков распределены ненормально и имеется большое количество категориальных признаков, то анализ корреляции будем проводить с помощью библиотеки phik.

# %%
#вычисление матрицы корреляции
matrix = data_train.drop(['id'], axis=1).phik_matrix(interval_cols=['salary'])


#визуализация матрицы корреляции 
plt.figure(figsize=(15, 15))
sns.heatmap(corr_matrix, annot=True, cmap='Greens')
plt.title('Корреляция признаков для "data_train"')
plt.show()

# %% [markdown]
# Коэффициенты корреляции аналогичны полученным ранее, на первой тренировочной выборке. В Задаче1.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Перед исследованием портрета клиента важно провести общий EDA (распределение и корреляция) для новой `train` выборки по аналогии с первой задачей.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# Построим графики для всех данных из нашего основного датасета. И сравним оставшихся и ушедших работников.
# **Слева - оставшиеся, справа ушедшие сотрудники**.

# %%
data_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
#дбавим целевые признаки в тестовую выборку
df1 = df_test.merge(df_target, how='left')
df1 = df1.merge(data_target, how='left')
df1.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate  \
# 0                   no                      5   28800                   0.79
# 1                   no                      4   30000                   0.72
# 2                   no                      4   19200                   0.64
# 3                   no                      4   19200                   0.60
# 4                   no                      5   40800                   0.75
#
#   quit
# 0   no
# 1   no
# 2   no
# 3   no
# 4   no

# %%
data_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %%
data_train_cat_col = ['dept', 
           'level', 
           'workload', 
           'last_year_promo', 
           'last_year_violations']

data_train_num_col = ['employment_years', 
           'supervisor_evaluation']

data_train_continuous_col = ['salary']

# %%
for i in data_train_num_col:
    fig, ax = plt.subplots(1, 2, figsize=(15, 15))
    data_train_group_yes = data_train[data_train['quit'] == 'yes'].groupby(i)['id'].count().sort_values(ascending=False)
    data_train_group_no = data_train[data_train['quit'] == 'no'].groupby(i)['id'].count().sort_values(ascending=False)
    
    labels = data_train_group_yes.index
    colours = dict(zip(labels, plt.cm.tab10.colors[:len(labels)]))
    ax[0].pie(data_train_group_no, labels=labels, autopct='%1.1f%%', colors=[colours[key] for key in labels])
    ax[1].pie(data_train_group_yes, labels=labels, autopct='%1.1f%%', colors=[colours[key] for key in labels])
    plt.title(f'Распределение для работающих и уволившихся {i}');
    plt.show()

# %%
sns.histplot(data = data_train.loc[data_train['quit']=='no'], x='salary')
plt.xlabel('Доход')
plt.title('Распределение дохода у оставшихся сотрудников')
plt.show()

# %%
sns.histplot(data = data_train.loc[data_train['quit']=='yes'], x='salary')
plt.xlabel('Доход')
plt.title('Распределение дорхода у уволившихся сотрудников')
plt.show()

# %% [markdown]
# ВЫВОД:
# Ожидаемо, уровень дохода покинувших компанию - 15-30 тр. У оставшихся 30-50 тр + высокие зарплаты у руководителей и экспертов 70-100 тр

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Дискретные признаки по аналогии с категориальными/бинарными следует оценить с помощнью относительных значений - подойдёт то же решение с круговыми диаграммами, которое есть ниже. Для `salary` не забудь про офомрление графиков - часть из них не оформлена совсем, на другой части не хватает обязательных атрибутов.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Левый график не оформлен.
#
# <br/>
# <div class="alert alert-info">
# переделал
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ментора v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# **п. 3.3.  Проверка уровня влияния показателя "job_satisfaction_rate" в разрезе 'quit'**
#
# <br/>
# <div class="alert alert-info">
# ВОТ проверка влияния, до ввода дополнительного признака в 4м ШАГЕ
#
# </div>

# %%
df1[df1['quit'] == 'no']['job_satisfaction_rate'].hist(bins=30, density=True)
plt.title('Распределение job_satisfaction_rate у оставшихся сотрудников')
plt.ylabel('Количество')
plt.xlabel('job_satisfaction_rate')
plt.show();

df1[df1['quit'] == 'yes']['job_satisfaction_rate'].hist(bins=30, density=True)
plt.title('Распределение job_satisfaction_rate у уволившихся сотрудников')
plt.ylabel('Количество')
plt.xlabel('job_satisfaction_rate')
plt.show();

# %% [markdown]
# **ВЫВОД**
# как мы видим, показатель удовлетвренности обладает высоким уровнем корреляции с вероятностью ухода. У покинувших компанию сотрудников уровень удовлетворенности в основном на уровне 0,2-0,4. У оставшихся - 0,6-0,8.

# %%
data1 = data_train[data_train['quit'] == 'no']
data2 = data_train[data_train['quit'] == 'yes']

# %%
ax=sns.boxplot(data = data1, x = 'employment_years')
ax.set_xlabel('Стаж в годах')
ax.set_title('Распределение стажа для оставшихся сотрудников')
plt.show()

# %%
ax = sns.boxplot(data = data2, x = 'employment_years')
ax.set_xlabel('Стаж в годах')
ax.set_title('Распределение стажа для уволившихся сотрудников')
plt.show()

# %%
ax = sns.boxplot(data = data1, x = 'supervisor_evaluation')
ax.set_xlabel('Оценка')
ax.set_title('Распределение оценок руководства для оставшихся сотрудников')
plt.show()

# %%
ax = sns.boxplot(data = data2, x = 'supervisor_evaluation')
ax.set_xlabel('Оценка')
ax.set_title('Распределение оценок руководства для уволившихся сотрудников')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Левый ряд графиков не оформлен.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
print(data_train[data_train['quit'] == 'yes']['salary'].median())
print(data_train[data_train['quit'] == 'no']['salary'].median())
# Out:
# 22800.0
# 34800.0

# %%
for i in data_train_cat_col:
    fig, ax = plt.subplots(1, 2, figsize=(20,5))
    data_train_group_yes = data_train[data_train['quit'] == 'yes'].groupby(i)['salary'].count().sort_values(ascending=False)
    data_train_group_no = data_train[data_train['quit'] == 'no'].groupby(i)['salary'].count().sort_values(ascending=False)
    
    labels = data_train_group_yes.index
    colours = dict(zip(labels, plt.cm.tab10.colors[:len(labels)]))
    ax[0].pie(data_train_group_no, labels=labels, autopct='%1.1f%%', colors=[colours[key] for key in labels])
    ax[1].pie(data_train_group_yes, labels=labels, autopct='%1.1f%%', colors=[colours[key] for key in labels])
    plt.title(f'Распределение для работающих и уволившихся {i}');
    plt.show()

# %% [markdown]
# + Портрет уволившегося сотрудника :

# %% [markdown]
# Мы видим, что бэк-офисные сотрудники (кадры, закупки, маркетинг) меньше подвержены ротации. Продающие подразделения и технологи/ит-шники чаще увольняются. Это более массовые профессии и , возможно, они/им легче находят замену.
#
# Подавляющее большинство уволившихся - сотрудники нижнего звена, с минимальным опытом. Им особо нечего терять, и за них не держится компания.
#
# Также видим, что слабозагруженные сотрудники предпочитают выжидать, а среднезагруженные, при этом малооплачиваемые, готовы искать другие варианты. Топы и эксперты хорошо получают и держатся за работу.
#
# Понятно, что давно не повышаемые сотрудники не сильно мотивированы оставаться.
#
# Также очевидно, что сотрудники, получившие взыскание, либо не ценят текущую работу, либо понимают, что им мало что светит, после конфликтной ситуации. И уходят.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Проанализирован портрет уволившегося сотрудника. Молодец, что используешь относительные величины для анализа категориальных признаков, а также сравниваешь зарплату между выборками с помощью средних.

# %% [markdown]
# **Шаг 4. Добавление нового входного признака**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Добавление нового признака выполняется после задания `3.3`, ведь именно по его результату мы принимаем решение о том, нужно ли его в принципе добавлять.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не учтено - признак нужно добавить после анализа распределения `job_satisfaction_rate` в разрезе `quit`, когда мы будем понимать, есть ли разница и стоит ли его вообще добавлять.
#
# <br/>
# <div class="alert alert-info">
# АЛЕКСЕЙ !
#
# СМ ВЫШЕ  **п 3.3**
# **Проверка уровня влияния показателя "job_satisfaction_rate" в разрезе 'quit'**
#
# ВЫВОД
# как мы видим, показатель удовлетвренности обладает высоким уровнем корреляции с вероятностью ухода. У покинувших компанию сотрудников уровень удовлетворенности в основном на уровне 0,2-0,4. У оставшихся - 0,6-0,8.
#
#
# Сделано до ШАГА 4.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Ага, понял, спасибо, что подсветил, куда смотреть. На будущее рекомендую сразу оставлять указание для ревьюера, где была сделана доработка, если она сделана не в той части проекта, которая предусмотрена условием проекта - в нашем случае это не повлияло на дополнительную итерацию, так как были и другие замечания, но могло бы случиться и так, что итерация была бы потеряна.

# %%
#добавление нового входного признака
data_train['job_satisfaction_rate'] = best_model.predict(data_train)

# %%
data_train.sort_values(by = 'id', ascending = True)
# Out:
#           id        dept   level workload  employment_years last_year_promo  \
# 2600  100222       sales  junior   medium                 3              no
# 717   100459  purchasing  junior   medium                 3              no
# 2455  100469   marketing  junior   medium                 1              no
# 1592  100601  technology  middle     high                 4              no
# 2657  100858       sales  junior   medium                 2              no
# ...      ...         ...     ...      ...               ...             ...
# 2194  998517  purchasing  middle      low                 5              no
# 3701  999003          hr  middle      low                 3              no
# 3364  999158  purchasing  junior   medium                 1              no
# 18    999835       sales  junior      low                 5              no
# 2120  999915          hr  middle      low                 5              no
#
# ...

# %%
plt.figure(figsize=(16,10))
plt.title('Распределение коэффициента удовлетворенности уволенных и оставшихся.', fontsize=16, fontweight="bold", color='blue')
plt.xlim (data_train['job_satisfaction_rate'].min(), data_train['job_satisfaction_rate'].max())
ax = data_train['job_satisfaction_rate'][data_train['quit'] == 'yes'].plot.kde(color='red')
ax = data_train['job_satisfaction_rate'][data_train['quit'] == 'no'].plot.kde(color='blue')
ax.set_ylabel('Плотность', fontsize=20, fontweight="bold", color='blue')

None

# %% [markdown]
# ВЫВОД
# коэффициент удовлетворенности у работающих - выше 0.6 (0.7-0.85). У ушедших заемтно ниже - менее 0.5 (0.2 - 0.35).
# Таким образом, его влияние на дейстия сотрудников очевидно и требует существенного внимания со стороны менеджмента и владельцев.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследовано распределение удовлетворённости в зависимости от факта ухода. Молодец, что используешь нормированную гистограмму.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Чуть более интересным решением, позволяющим выполнить оценку не "на глаз", а более статистически достоверно, было бы использование статистического теста (например, `ttest`) для сравнения распределений в выборках.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. Анализ должен быть выполнен по `test` выборке (см.условие проекта) - для этого по `id` в новую выборку нужно соединить целевые признаки обеих задач.
#
# 2. Анализ должен быть выполнен по реальным, а не предсказанным значениям: реальные значения мы можем использовать для анализа исторических данных, так как они содержат важные паттерны для анализа зависимостей, которые также запоминает и модель, но чтобы иметь возможность работать с новыми работниками без исторических данных, модель должна использовать признак на основе предсказаний.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Кажется, всё же нет - ты проводишь анализ по `train` выборке и на основе предсказанных значений.
#
# <br/>
# <div class="alert alert-info">
# АЛЕКСЕЙ
#
# df1 - это test c целевыми признаками
# см ВЫШЕ, после Корреляции
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Да, выше сделано корректно.

# %%
# df1 = df_test.merge(df_target, how='left')
# df1 = df1.merge(data_target, how='left')
#визуализируем средние показатели удовлетвоенности для ушедших и работающих
depart = df1['job_satisfaction_rate'][df1['quit'] == 'yes'].mean()
work = df1['job_satisfaction_rate'][df1['quit'] == 'no'].mean()
data = [depart, work]
labels = ['Ушедшие сотрудники', 'Оставшиеся сотрудники']
plt.figure(figsize=(8,8))
plt.rc('font', size= 20 ) 

fbcolor = ["red", "grey"]

explode = [0.02, 0.05]

plt.pie(data, labels = labels, explode = explode, colors = fbcolor, autopct='%.1f%%', textprops={'color':'b'}, normalize=False)
plt.title('Средние показатели уровня удовлетворенности', fontsize=20, fontweight="bold", color='blue')
plt.xlabel(f'\nСредний коэффициент для ушедших {round(depart,3)}\n для работающих {round(work,3)}', fontsize=20, fontweight="bold", color='blue')
plt.show()

# %% [markdown]
# + Практически, разница в 1,5 раза. Параметр должен быть в фокусе у кадровой службы и руководства организации. Соответственно, кадровая стратегия должна выстраиваться с учетом данного показателя.

# %%
df1[df1['quit'] == 'no']['salary'].hist(bins=30, density=True)
plt.title('Распределение дохода у оставшихся сотрудников')
plt.ylabel('Количество')
plt.xlabel('Доход')
plt.show();
df1[df1['quit'] == 'yes']['salary'].hist(bins=30, density=True)
plt.title('Распределение дохода у уволившихся сотрудников')
plt.ylabel('Количество')
plt.xlabel('Доход')
plt.show();

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Тут нужна обычная гистограмма, а не `bar`, так как у признака по `X` слишком много уникальных значений.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# + Как мы видим, уходят в основном сотрудникик с доходом около 20тр. У оставшихся доход 30-60 тр, а также, для группы руководителей/экспертов - 80 -100 тр.

# %% [markdown]
# **Шаг 5. Подготовка данных**

# %% [markdown]
# Как и в первой задаче, данные делятся на три группы.
#
# 1.dept, last_year_promo, last_year_violations — кодируем OneHotEncoder.
# 2.level, workload — с помощью OrdinalEncoder.
# 3.employment_years, supervisor_evaluation, salary, job_satisfaction_rate - масштабируем.
#
# Пропуски заполним в пайплайне.
# Теперь целевой признак — quit.

# %%
data_train.describe()
# Out:
#                   id  employment_years  supervisor_evaluation        salary  \
# count    4000.000000       4000.000000            4000.000000   4000.000000
# mean   552099.283750          3.701500               3.474750  33805.800000
# std    260158.031387          2.541852               1.004049  15152.415163
# min    100222.000000          1.000000               1.000000  12000.000000
# 25%    327785.750000          2.000000               3.000000  22800.000000
# 50%    546673.000000          3.000000               4.000000  30000.000000
# 75%    781497.750000          6.000000               4.000000  43200.000000
# max    999915.000000         10.000000               5.000000  96000.000000
#
#        job_satisfaction_rate
# count            4000.000000
# mean                0.537214
# std                 0.218353
# min                 0.030000
# 25%                 0.350000
# 50%                 0.550000
# 75%                 0.688667
# max                 1.000000

# %%
data_train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit  \
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no
#
#    job_satisfaction_rate
# 0               0.660000
# 1               0.853529
# 2               0.364091
# 3               0.380000
# 4               0.690000

# %%
#добавляем предсказания нашей модели
data_test['job_satisfaction_rate'] = best_model.predict(data_test)
data_test[data_test.columns[data_test.columns != 'id']].describe()
data_test.head()
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      5   28800               0.863333
# 1                   no                      4   30000               0.670417
# 2                   no                      4   19200               0.654000
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В выборки добавлен новый признак на основе предсказаний модели из предыдущей задачи.

# %%
data_target.head()
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %% [markdown]
# **Шаг 6. Обучение модели**

# %%
target_all_2 = data_target.merge(data_test, how='left')
display(target_all_2.head())
target_all_2[target_all_2.columns[target_all_2.columns != 'id']].describe()
# Out:
#        id quit        dept   level workload  employment_years last_year_promo  \
# 0  999029  yes  technology  junior   medium                 1              no
# 1  372846   no       sales  middle   medium                10              no
# 2  726767   no   marketing  middle      low                 7              no
# 3  490105   no  purchasing  middle      low                 7              no
# 4  416898  yes  purchasing  junior      low                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      3   31200                  0.335
# 1                  yes                      2   32400                  0.220
# 2                   no                      4   20400                  0.670
# 3                   no                      4   19200                  0.695
# 4                   no                      4   12000                  0.510
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Кодирование нельзя делать руками:
# - при появлении новых значений категориальных признаков, не предусмотренных твоим решением, модель или упадёт, или будет генерировать ошибки;
# - такое решение не сделаешь частью `pipeline`, а все современные решения базируются на них.
#
# Поэтому кодирование нужно делать только с применением обучаемых трансформеров. Для кодирования целевого признака нужно использовать `LabelEncoder` (https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html).
#
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
train_2 = data_train.drop(['id'], axis=1)
train_2.drop_duplicates(inplace=True)
test_2 = target_all_2.drop(['quit','id'], axis=1)
target_2 = target_all_2['quit']

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Аналогично неиспользуемая переменная.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
#формируем выборки
X_train = train_2.drop('quit', axis=1)
y_train = train_2['quit'] 
X_test = test_2
y_test = target_2

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)


RANDOM_STATE = 100

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Аналогично про `copy()`.

# %%
#создаем списки для типов признаков
ohe_columns = ['dept', 'last_year_promo', 'last_year_violations']
ord_columns = ['level', 'workload']
num_columns = ['employment_years', 'supervisor_evaluation', 'salary', 'job_satisfaction_rate']

#заполняем пропуски
#настраиваем модели
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
    ]
)

ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ord',  OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'], 
                    ['low', 'medium', 'high']
                ], 
                handle_unknown='use_encoded_value', unknown_value=np.nan
            )
        ),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Не забывай про настройку `random_state` у моделей - выше и ниже.
#
# <br/>
# <div class="alert alert-info">
# исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
 
param_grid = [

    {
        'models': [RandomForestClassifier(random_state=RANDOM_STATE)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(5, 15),
        'models__max_features': range(5, 15),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(10, 20),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    }
]

#настроим перебор гиперпараметров
#используем метрику roc-auc, в связи с дисбалансом признаков
grid_search = GridSearchCV(
    pipe_final,
    param_grid,
    n_jobs=-1,
    cv=5,
    scoring='roc_auc'
)
grid_search.fit(X_train, y_train)

# %%
best_model = grid_search.best_estimator_
print('Лучшая модель:\n\n', grid_search.best_estimator_)
print(f'Метрика ROC-AUC на обучающих данных: {round(grid_search.best_score_,4)}')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Найдена лучшая модель.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Обрати внимание, что оценка получена на кросс-валидации, а не на `train` выборке - очень важно корректно разделять эти сущности.
#
# На `train` оценка выглядела бы сделующим образом:
#
#     model.fit(x_train, y_train)
#     preds = model.predict(x_train)
#
#     smape(y_train, preds)
#
# Текст в выводе кода стоит поправить, указав оценку на кросс-валидации.

# %%
print(f'Метрика ROC-AUC на тестовых данных: {round(roc_auc_score(y_test, grid_search.predict_proba(X_test)[:, 1]),4)}')

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Лучшую модель оценили на `test` - отличный результат!

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Аналогично стоит выполнить оценку модели на адеватность - в случае задачи классификации мы можем использовать  `DummyClassifier` (https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html#sklearn.dummy.DummyClassifier).

# %% [markdown]
# **Шаг 7. Выводы**

# %% [markdown]
# ВЫВОД по Задаче_2
#
# + сотрудники чаще уходят из продающих подразделений, реже из бэк-офисных.
# + почти 90% ушедших сотрудников начинающие/неопытные.
# + у уволившихся сотрудников уровень занятости выше низкого уровня.
# + почти все уволившиеся не повышались.
# + 20% уволившихся сотрудников получили взыскания в прошлом году. у оставшихся этот показатель в 2 раза ниже.
# + большинство ушедших сотрудников проработало менее 4 лет.
# + распределения оценки от руководителя у оставшихся сотрудников выше, чем у ущедщих.
# + аналогично, арплата у ушедших меньше.
# + признак job_satisfaction_rate существенно связан с уходом сотрудника.
#
# На основании метрики ROC-AUC нами отобрана лучшая модель ('models', KNeighborsClassifier(n_neighbors=17)). Показатель на тестовой выборке выше полученного на тренировочных.

# %% [markdown]
# **Общий вывод :**

# %% [markdown]
# Итоговый вывод:
#
# Решаемые задачи: 1.построить модель, предсказывающую уровень удовлетворённости сотрудника на основе данных заказчика. Для бизнеса важно прогнозировать и регулировать возможные отток сотрудников. Особенно это касается массовых увольнений или ухода ключевых специалистов/менеджеров.
# 2.построить модель, предсказывающую вероятность уходы сотрудника из компании.
#
# При решении задач 1 и 2 пройдены следующие этапы:
#
# Загрузка и первичное изучение данных
# Предобработка данных: данные были проверены на пропуски и дубликаты
# Исследовательский анализ данных: построение графиков, матриц корелляции
# Подготовка данных: написание пайплайнов для подготовки данных (кодирование, масштабирование)
# Обучение модели: формирование пайплайна с перебором моделей
#
# Рекомендации менеджменту и владельцам по снижению уровня увольнений:
#
# Выше указал, что больше всего уволилось сотрудников из отделов sales, technology. Имеет смысл провести доп. опросы данных отделов.
# 80% из уволившихся - уровень junior, работают от 1 до 3х лет - следует уделить внимание адаптации новичков.
# Почти у 100% уволившихся не было повышения за последний год - нужна прозрачная модель карьерного развития.
# Средняя зааботная плата неуволившегося сотрудника существенно больше, чем у ушедших - возможно сетку зарплат стоит скорректировать.
# Есть заметная зависимость между увольнением и удовлетворённостью сотрудника. Используя разработанную модель, можно предсказывать удовлетворённость сотрудников. Соответственно, появляется возможность уточнить причины снижения удовлетворенности и принимать соответствующие (выше) комплексные меры.

# %% [markdown]
# <div class="alert alert-success">
#
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть итоговый вывод и рекомендации - отлично!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Алексей, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Работа с моделями также выполнена отлично: исследовано несколько алгоритмов, проведён подбор гиперпараметров с помощью `GridSearchCV`, выполнена промежуточная оценка моделей на кросс-валидации - молодец! Здорово, что используешь сочетание `ColumnTransformer` и `Pipeline` для соединения разных инструментов в единый модельный объект и настраиваешь бесперебойную работу энкодера в случае появления в данных новых, неизвестных на момент обучения значений признаков - так твоё решение будет более гибким и масштабируемым.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)
#
#
# <br/>
# <div class="alert alert-info">
# АЛЕКСЕЙ
#
# До дедлайна остался один день.
# Исправил "красные" ошибки
#
#
# в двух случаях дал необходимые пояснения.
#
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: итоговый вывод по проекту.
#
# Алексей, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейшем обучении:)
